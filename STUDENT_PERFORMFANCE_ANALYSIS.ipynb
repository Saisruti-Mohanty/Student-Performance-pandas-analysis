# %%
import pandas as pd
df=pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.isna().sum #check missing values in dataset,TRUE-MISSING VALUE,FALSE-VALUE PRESENT
#SUM-COUNTS THE TRUE VAUES IN EACH COLUMN
# Out:
# <bound method DataFrame.sum of      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
df.notna() #checks non missing values/notnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0      True            True                         True   True
# 1      True            True                         True   True
# 2      True            True                         True   True
# 3      True            True                         True   True
# 4      True            True                         True   True
# ..      ...             ...                          ...    ...
# 995    True            True                         True   True
# 996    True            True                         True   True
# 997    True            True                         True   True
# 998    True            True                         True   True
# 999    True            True                         True   True
#
#      test preparation course  math score  reading score  writing score
# 0                       True        True           True           True
# ...

# %%
#df.reindex(new_index)
new_index=[10,5,0,2]
df.reindex(new_index)
# Out:
#     gender race/ethnicity parental level of education     lunch  \
# 10    male        group C          associate's degree  standard
# 5   female        group B          associate's degree  standard
# 0   female        group B           bachelor's degree  standard
# 2   female        group B             master's degree  standard
#
#    test preparation course  math score  reading score  writing score
# 10                    none          58             54             52
# 5                     none          71             83             78
# 0                     none          72             72             74
# 2                     none          90             95             93

# %%
new_index=[10,5,0,2,1001]
df.reindex(new_index) #row 1001 does not exist so it create it with NAN VALUES
# Out:
#       gender race/ethnicity parental level of education     lunch  \
# 10      male        group C          associate's degree  standard
# 5     female        group B          associate's degree  standard
# 0     female        group B           bachelor's degree  standard
# 2     female        group B             master's degree  standard
# 1001     NaN            NaN                         NaN       NaN
#
#      test preparation course  math score  reading score  writing score
# 10                      none        58.0           54.0           52.0
# 5                       none        71.0           83.0           78.0
# 0                       none        72.0           72.0           74.0
# 2                       none        90.0           95.0           93.0
# 1001                     NaN         NaN            NaN            NaN

# %%
df.reindex(columns=[
    "gender",
    "lunch",
    "math score",
    "reading score",
    "writing score"
])
#this will show only these columns
# Out:
#      gender         lunch  math score  reading score  writing score
# 0    female      standard          72             72             74
# 1    female      standard          69             90             88
# 2    female      standard          90             95             93
# 3      male  free/reduced          47             57             44
# 4      male      standard          76             78             75
# ..      ...           ...         ...            ...            ...
# 995  female      standard          88             99             95
# 996    male  free/reduced          62             55             55
# 997  female  free/reduced          59             71             65
# 998  female      standard          68             78             77
# 999  female  free/reduced          77             86             86
#
# [1000 rows x 5 columns]

# %%
df.reindex(columns=list(df.columns)+["total_score"])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
new_index=range(0,1010)
df.reindex(new_index,fill_value=10)
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 1005      10             10                          10            10
# 1006      10             10                          10            10
# 1007      10             10                          10            10
# 1008      10             10                          10            10
# 1009      10             10                          10            10
#
#      test preparation course  math score  reading score  writing score
# ...

# %%
df.columns #view all cols
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#count values
df["gender"].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
df["race/ethnicity"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      group B
# 1      group C
# 2      group B
# 3      group A
# 4      group C
#         ...
# 995    group E
# 996    group C
# 997    group C
# 998    group D
# 999    group D
# Name: race/ethnicity, Length: 1000, dtype: object>

# %%
df["race/ethnicity"].unique() #unique values
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
#check membership
df["gender"].isin(["female"])
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %%
#select rows using labels
#syntax df.loc[row_label,column_label]
df.loc[9:15]  #included end index
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# 13    male        group A                some college      standard
# 14  female        group A             master's degree      standard
# 15  female        group C            some high school      standard
#
#    test preparation course  math score  reading score  writing score
# 9                     none          38             60             50
# 10                    none          58             54             52
# 11                    none          40             52             43
# 12                    none          65             81             73
# 13               completed          78             72             70
# ...

# %%
#loc with condition
df.loc[df["math score"]<70]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.loc[1:5,"gender"]
# Out:
# 1    female
# 2    female
# 3      male
# 4      male
# 5    female
# Name: gender, dtype: object

# %%
#iloc-INTEGER BASED POSITION,SELECTS DATA USING INTEGER POSITIONS(INDEX NUMBERS)
#syntax df.loc[row_POSITION,column_POSITION]
df.iloc[1]
# Out:
# gender                               female
# race/ethnicity                      group C
# parental level of education    some college
# lunch                              standard
# test preparation course           completed
# math score                               69
# reading score                            90
# writing score                            88
# Name: 1, dtype: object

# %%
df.iloc[7:10,0] #end index is NOT INCLUDED IN iloc
# Out:
# 7      male
# 8      male
# 9    female
# Name: gender, dtype: object

# %% [raw]
# # df.index=[100,101,102...]
# df.loc[9:15] ##ERRROR
# df.iloc[9:15] ##RIGHT

# %%
#selectimg columns
df.iloc[0:6][["math score","gender","lunch"]]
# Out:
#    math score  gender         lunch
# 0          72  female      standard
# 1          69  female      standard
# 2          90  female      standard
# 3          47    male  free/reduced
# 4          76    male      standard
# 5          71  female      standard

# %%
df.sort_values("math score")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 625    male        group D                some college      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# 962  female        group E          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.sort_values("math score",ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.sort_index()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df["reading score"].max()
# Out:
# 100

# %%
df["math score"].min()
# Out:
# 0

# %%
df["math score"].mean()
# Out:
# np.float64(66.089)

# %%
df["math score"].sum()
# Out:
# np.int64(66089)

# %%
df["math score"].cumsum() #cumulative sum it keps adding the values one by one and shhws the running totaldf["math score"].min()
# Out:
# 0         72
# 1        141
# 2        231
# 3        278
# 4        354
#        ...
# 995    65823
# 996    65885
# 997    65944
# 998    66012
# 999    66089
# Name: math score, Length: 1000, dtype: int64

# %%
df["math score"].idxmax() #returns the row number(index) where the max value occurs
# Out:
# 149

# %%
df.loc[df["math score"].idxmax()]
#math score max is 100
#index 149 by idxmax
#*****loc retrives the entire row with index 149*****
# Out:
# gender                                       male
# race/ethnicity                            group E
# parental level of education    associate's degree
# lunch                                free/reduced
# test preparation course                 completed
# math score                                    100
# reading score                                 100
# writing score                                  93
# Name: 149, dtype: object

# %%
df["math score"].idxmin()
# Out:
# 59

# %%
df["math score"].rank() #ASSIGN A RANK TO EACH VALUE,THE SMALLEST VALUE GETS RANK 1,LARGEST VALUE GETS THE HIGHEST RANK
#WHEN THERE IS A TIE PANDAS GIVES THE AVERAGE RAMK
# Out:
# 0      644.5
# 1      575.5
# 2      946.5
# 3      102.0
# 4      737.0
#        ...
# 995    929.0
# 996    384.0
# 997    307.5
# 998    546.5
# 999    759.5
# Name: math score, Length: 1000, dtype: float64

# %%
#CORRELATION BETWEEN SCORES
df[["math score","reading score","writing score"]].corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
df[["math score","reading score","writing score"]].cov()
# Out:
#                math score  reading score  writing score
# math score     229.918998     180.998958     184.939133
# reading score  180.998958     213.165605     211.786661
# writing score  184.939133     211.786661     230.907992

# %%
df["total score"] = df["math score"] + df["reading score"] + df["writing score"]
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229
